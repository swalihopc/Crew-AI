# %%
# !pip install crewai-tools==0.25.0
# !pip install crewai==0.86.0
# !pip install langchain_community==0.0.29
# Out:
# Requirement already satisfied: crewai-tools==0.25.0 in /usr/local/lib/python3.11/dist-packages (0.25.0)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (4.13.4)
# Requirement already satisfied: chromadb>=0.4.22 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.5.23)
# Requirement already satisfied: crewai>=0.86.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.86.0)
# Requirement already satisfied: docker>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.9)
# Requirement already satisfied: embedchain>=0.1.114 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.1.128)
# Requirement already satisfied: lancedb>=0.5.4 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.24.0)
# Requirement already satisfied: openai>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (1.93.0)
# Requirement already satisfied: pydantic>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (2.11.7)
# Requirement already satisfied: pyright>=1.1.350 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (1.1.403)
# Requirement already satisfied: pytest>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (8.3.5)
# Requirement already satisfied: pytube>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (2.32.3)
# Requirement already satisfied: scrapegraph-py>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (1.14.1)
# Requirement already satisfied: selenium>=4.18.1 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (4.34.2)
# Requirement already satisfied: serpapi>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai-tools==0.25.0) (0.1.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.12.3->crewai-tools==0.25.0) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.12.3->crewai-tools==0.25.0) (4.14.1)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.115.14)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools==0.25.0) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (3.25.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.4.22->crewai-tools==0.25.0) (13.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (4.10.0)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (8.2.1)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.9.2)
# Requirement already satisfied: json-repair>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (0.25.2)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.72.6)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (3.1.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (0.11.7)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.11/dist-packages (from crewai>=0.86.0->crewai-tools==0.25.0) (0.7.20)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker>=7.1.0->crewai-tools==0.25.0) (2.5.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (1.16.3)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.3.26)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.3.5)
# Collecting langchain-community<0.4.0,>=0.3.1 (from embedchain>=0.1.114->crewai-tools==0.25.0)
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.2.14)
# Collecting langsmith<0.4.0,>=0.3.18 (from embedchain>=0.1.114->crewai-tools==0.25.0)
#   Using cached langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.54 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.1.114)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (5.7.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /usr/local/lib/python3.11/dist-packages (from embedchain>=0.1.114->crewai-tools==0.25.0) (2.0.41)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools==0.25.0) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools==0.25.0) (23.2)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.11/dist-packages (from lancedb>=0.5.4->crewai-tools==0.25.0) (18.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.12.0->crewai-tools==0.25.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.12.0->crewai-tools==0.25.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.12.0->crewai-tools==0.25.0) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.12.0->crewai-tools==0.25.0) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.6.1->crewai-tools==0.25.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.6.1->crewai-tools==0.25.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.6.1->crewai-tools==0.25.0) (0.4.1)
# Requirement already satisfied: nodeenv>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from pyright>=1.1.350->crewai-tools==0.25.0) (1.9.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=8.0.0->crewai-tools==0.25.0) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.0.0->crewai-tools==0.25.0) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->crewai-tools==0.25.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->crewai-tools==0.25.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->crewai-tools==0.25.0) (2025.6.15)
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.11/dist-packages (from scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (3.11.15)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.18.1->crewai-tools==0.25.0) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.18.1->crewai-tools==0.25.0) (0.12.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium>=4.18.1->crewai-tools==0.25.0) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10->scrapegraph-py>=1.8.0->crewai-tools==0.25.0) (1.20.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools==0.25.0) (1.1.3)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools==0.25.0) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools==0.25.0) (2.10.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.4.22->crewai-tools==0.25.0) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi>=0.95.2->chromadb>=0.4.22->crewai-tools==0.25.0) (0.46.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai-tools==0.25.0) (5.5.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.16.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (3.1.6)
# Requirement already satisfied: mkdocs-material>=9.5.49 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (9.6.15)
# Requirement already satisfied: mkdocs>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (1.6.1)
# Requirement already satisfied: pre-commit>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (4.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (2.38.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.10)
# Collecting langchain-core<1.0.0,>=0.3.66 (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0)
#   Downloading langchain_core-0.3.68-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (0.3.8)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (5.16.1)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (0.4.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.11/dist-packages (from langchain-openai<0.3.0,>=0.2.1->embedchain>=0.1.114->crewai-tools==0.25.0) (0.9.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools==0.25.0) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools==0.25.0) (0.23.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (8.7.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (4.24.0)
# Requirement already satisfied: pytz>=2024.1 in /usr/local/lib/python3.11/dist-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (1.14.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (1.13.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai>=0.86.0->crewai-tools==0.25.0) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.55b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai-tools==0.25.0) (3.9.1)
# Requirement already satisfied: pdfminer.six==20250506 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools==0.25.0) (20250506)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools==0.25.0) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai>=0.86.0->crewai-tools==0.25.0) (4.30.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai-tools==0.25.0) (2.2.1)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (3.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai-tools==0.25.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai-tools==0.25.0) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools==0.25.0) (3.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools==0.25.0) (0.33.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools==0.25.0) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools==0.25.0) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium>=4.18.1->crewai-tools==0.25.0) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.4.22->crewai-tools==0.25.0) (1.5.4)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium>=4.18.1->crewai-tools==0.25.0) (1.7.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools==0.25.0) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools==0.25.0) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools==0.25.0) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai-tools==0.25.0) (15.0.1)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (1.11.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (2.32.4.20250611)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools==0.25.0) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (0.9.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools==0.25.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools==0.25.0) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai-tools==0.25.0) (1.1.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (3.23.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai>=0.86.0->crewai-tools==0.25.0) (0.26.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (1.33)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.1.2)
# Requirement already satisfied: ghp-import>=1.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (2.1.0)
# Requirement already satisfied: markdown>=3.3.6 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (3.8.2)
# Requirement already satisfied: mergedeep>=1.3.4 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (1.1)
# Requirement already satisfied: watchdog>=2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (6.0.0)
# Requirement already satisfied: babel~=2.10 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (2.17.0)
# Requirement already satisfied: backrefs~=5.7.post1 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (5.9)
# Requirement already satisfied: colorama~=0.4 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.4.6)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (10.16)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools==0.25.0) (2025.2)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (2.6.12)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.11/dist-packages (from pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (20.31.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (2.10.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.22->crewai-tools==0.25.0) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.86.0->crewai-tools==0.25.0) (2.22)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (3.0.0)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai>=0.86.0->crewai-tools==0.25.0) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai-tools==0.25.0) (0.6.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools==0.25.0) (1.1.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai>=0.86.0->crewai-tools==0.25.0) (0.3.9)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools==0.25.0) (4.1.0)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Using cached langsmith-0.3.45-py3-none-any.whl (363 kB)
# Downloading langchain_core-0.3.68-py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.4/441.4 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: langsmith, langchain-core, langchain-community
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.53
#     Uninstalling langchain-core-0.1.53:
#       Successfully uninstalled langchain-core-0.1.53
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.29
#     Uninstalling langchain-community-0.0.29:
#       Successfully uninstalled langchain-community-0.0.29
# Successfully installed langchain-community-0.3.27 langchain-core-0.3.68 langsmith-0.3.45
# Requirement already satisfied: crewai==0.86.0 in /usr/local/lib/python3.11/dist-packages (0.86.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (4.10.0)
# Requirement already satisfied: chromadb>=0.5.18 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (8.2.1)
# Requirement already satisfied: crewai-tools>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.25.0)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.9.2)
# Requirement already satisfied: json-repair>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.25.2)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.72.6)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.93.0)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.11.7)
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (2.11.7)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.11/dist-packages (from crewai==0.86.0) (0.7.20)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai==0.86.0) (3.11.15)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai==0.86.0) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai==0.86.0) (2.10.1)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai==0.86.0) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai==0.86.0) (2.5.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.115.14)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.18->crewai==0.86.0) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (3.25.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (1.22.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.55b1)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.18->crewai==0.86.0) (13.9.4)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (4.13.4)
# Requirement already satisfied: docker>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (0.9)
# Requirement already satisfied: embedchain>=0.1.114 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (0.1.128)
# Requirement already satisfied: lancedb>=0.5.4 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (0.24.0)
# Requirement already satisfied: pyright>=1.1.350 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (1.1.403)
# Requirement already satisfied: pytest>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (8.3.5)
# Requirement already satisfied: pytube>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (15.0.0)
# Requirement already satisfied: scrapegraph-py>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (1.14.1)
# Requirement already satisfied: selenium>=4.18.1 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (4.34.2)
# Requirement already satisfied: serpapi>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai-tools>=0.17.0->crewai==0.86.0) (0.1.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai==0.86.0) (0.16)
# ...
# Requirement already satisfied: cohere<6.0,>=5.5.6 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (5.16.1)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2.2.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.4.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.18->crewai==0.86.0) (0.1.2)
# Requirement already satisfied: pytz>=2024.1 in /usr/local/lib/python3.11/dist-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (1.14.3)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai==0.86.0) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.86.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai==0.86.0) (0.2.13)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (3.2.3)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools>=0.17.0->crewai==0.86.0) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium>=4.18.1->crewai-tools>=0.17.0->crewai==0.86.0) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium>=4.18.1->crewai-tools>=0.17.0->crewai==0.86.0) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium>=4.18.1->crewai-tools>=0.17.0->crewai==0.86.0) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai==0.86.0) (0.3.9)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai==0.86.0) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.18->crewai==0.86.0) (1.3.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (1.11.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2.32.4.20250611)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (1.33)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2025.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.18->crewai==0.86.0) (0.6.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (2.10.1)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.11/dist-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (4.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (1.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools>=0.17.0->crewai==0.86.0) (4.1.0)
# Collecting langchain_community==0.0.29
#   Using cached langchain_community-0.0.29-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (3.11.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (0.6.7)
# Collecting langchain-core<0.2.0,>=0.1.33 (from langchain_community==0.0.29)
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain_community==0.0.29)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community==0.0.29) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (2.11.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community==0.0.29) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community==0.0.29) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community==0.0.29) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community==0.0.29) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.0.29) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.0.29) (4.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (0.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community==0.0.29) (1.3.1)
# Using cached langchain_community-0.0.29-py3-none-any.whl (1.8 MB)
# Using cached langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Installing collected packages: langsmith, langchain-core, langchain_community
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.45
#     Uninstalling langsmith-0.3.45:
#       Successfully uninstalled langsmith-0.3.45
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.68
#     Uninstalling langchain-core-0.3.68:
#       Successfully uninstalled langchain-core-0.3.68
#   Attempting uninstall: langchain_community
#     Found existing installation: langchain-community 0.3.27
#     Uninstalling langchain-community-0.3.27:
#       Successfully uninstalled langchain-community-0.3.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-cohere 0.3.5 requires langchain-core<0.4.0,>=0.3.27, but you have langchain-core 0.1.53 which is incompatible.
# langchain-openai 0.2.14 requires langchain-core<0.4.0,>=0.3.27, but you have langchain-core 0.1.53 which is incompatible.
# embedchain 0.1.128 requires langchain-community<0.4.0,>=0.3.1, but you have langchain-community 0.0.29 which is incompatible.
# embedchain 0.1.128 requires langsmith<0.4.0,>=0.3.18, but you have langsmith 0.1.147 which is incompatible.
# langchain-experimental 0.3.4 requires langchain-community<0.4.0,>=0.3.0, but you have langchain-community 0.0.29 which is incompatible.
# langchain-experimental 0.3.4 requires langchain-core<0.4.0,>=0.3.28, but you have langchain-core 0.1.53 which is incompatible.
# langchain-text-splitters 0.3.8 requires langchain-core<1.0.0,>=0.3.51, but you have langchain-core 0.1.53 which is incompatible.
# langchain 0.3.26 requires langchain-core<1.0.0,>=0.3.66, but you have langchain-core 0.1.53 which is incompatible.
# Successfully installed langchain-core-0.1.53 langchain_community-0.0.29 langsmith-0.1.147

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Simple Blog**

# %%
from crewai import LLM

llm = LLM(
    api_key="Your api key",
    model="groq/llama3-70b-8192"
)

# %% [markdown]
# ## Agents

# %%
from crewai import Agent, Task, Crew
planner = Agent(
    llm=llm,
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory="You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
    allow_delegation=False,
	verbose=True
)
writer = Agent(
    llm=llm,
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements."
              "Write the blog in a well-readable manner, partitioning it into sections as per the requirement. Ensure there are at least 5-6 sections, making the entire blog lengthier.",
    allow_delegation=False,
    verbose=True
)
editor = Agent(
    llm=llm,
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory="You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible.",
    allow_delegation=False,
    verbose=True
)

# %% [markdown]
# ## Tasks

# %%
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner,
)
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
)
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output="A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs.",
    agent=editor
)

# %% [markdown]
# Define Crew

# %%
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# Kick off

# %%
result = crew.kickoff(inputs={"topic": "Write a blog about us politcs"})
# Out:
# # Agent: Content Planner
# ## Task: 1. Prioritize the latest trends, key players, and noteworthy news on Write a blog about us politcs.
# 2. Identify the target audience, considering their interests and pain points.
# 3. Develop a detailed content outline including an introduction, key points, and a call to action.
# 4. Include SEO keywords and relevant data or sources.
#
#
# # Agent: Content Planner
# ## Final Answer:
# **Content Plan: "Understanding US Politics"**
#
# **I. Target Audience Analysis**
#
# * Demographics: Americans aged 18-55, interested in politics and current events
# * Interests: Staying informed about political news, understanding the impact of politics on their daily lives, making informed decisions at the polls
# * Pain Points: Feeling overwhelmed by biased media, struggling to understand complex political issues, wanting to engage in respectful political conversations
# * Goals: Gain a deeper understanding of US politics, stay up-to-date on current events, develop confident opinions on political issues
#
# **II. Content Outline**
#
# I. Introduction
#
# * Brief overview of the importance of understanding US politics
# * Thesis statement: By understanding the basics of US politics, individuals can make informed decisions and engage in respectful conversations about current events.
#
# II. The US Political System
#
# * Overview of the three branches of government (Legislative, Executive, Judicial)
# * Explanation of the role of political parties (Democratic, Republican, Third Parties)
# * Discussion of the electoral process (primary elections, general elections, Electoral College)
#
# III. Key Political Issues
#
# * Healthcare reform (Affordable Care Act, proposed changes)
# * Immigration policy (border control, DACA, proposed reforms)
# * Economic policy (tax reform, government spending, trade agreements)
# * Environmental policy (climate change, energy production, conservation)
#
# IV. Political Polarization and Biased Media
#
# * Discussion of the impact of social media on political discourse
# * Explanation of confirmation bias and its effects on political opinions
# * Tips for evaluating sources and avoiding bias in news consumption
#
# V. Call to Action
#
# * Encouragement to engage in respectful political conversations
# * Suggestions for staying informed about current events (news sources, podcasts, social media)
# * Resources for getting involved in the political process (voting, volunteering, contacting elected officials)
#
# **III. SEO Keywords**
#
# * US politics
# * Political system
# * Political parties
# * Electoral process
# * Healthcare reform
# * Immigration policy
# * Economic policy
# * Environmental policy
# * Political polarization
# * Biased media
# * Respectful political conversations
#
# **IV. Resources**
#
# * Pew Research Center: "Political Typology" (report on political polarization)
# * Brookings Institution: "A brief history of US immigration policy" (article)
# * Congressional Budget Office: "The Budget and Economic Outlook" (report)
# * National Institute of Environmental Health Sciences: "Climate Change" (article)
# * FactCheck.org: "How to Spot Fake News" (article)
# * USA.gov: "Contact Elected Officials" (resource list)
#
# By following this content plan, readers will gain a deeper understanding of US politics, stay up-to-date on current events, and develop confident opinions on political issues. The article will provide a comprehensive overview of the US political system, key political issues, and the impact of political polarization and biased media.
#
#
# # Agent: Content Writer
# ## Task: 1. Use the content plan to craft a compelling blog post on Write a blog about us politcs.
# 2. Incorporate SEO keywords naturally.
# 3. Sections/Subtitles are properly named in an engaging manner.
# 4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing conclusion.
# 5. Proofread for grammatical errors and alignment with the brand's voice.
#
#
#
# # Agent: Content Writer
# ## Final Answer:
# **Understanding US Politics: A Comprehensive Guide**
# =====================================================
#
# **The Importance of Staying Informed**
# -------------------------------------
#
# In today's politically charged climate, it's more crucial than ever to understand the basics of US politics. With the constant influx of news and opinions, it can be overwhelming to make sense of it all. However, by gaining a deeper understanding of the US political system, individuals can make informed decisions and engage in respectful conversations about current events. This article aims to provide a comprehensive overview of the US political system, key political issues, and the impact of political polarization and biased media.
#
# **The US Political System: A Breakdown**
# ----------------------------------------
#
# The US political system is composed of three branches of government: the Legislative, Executive, and Judicial branches. The Legislative branch, comprised of Congress, is responsible for making laws. The Executive branch, led by the President, carries out these laws. The Judicial branch, consisting of the Supreme Court, interprets these laws. In addition to these branches, political parties, such as the Democrats, Republicans, and Third Parties, play a significant role in shaping political discourse.
#
# The electoral process is another crucial aspect of US politics. Primary elections are held to select party nominees, followed by general elections, where voters choose between these nominees. The Electoral College, a system of electors who cast votes for president, is often a topic of discussion during election season.
#
# **Key Political Issues: Where Do You Stand?**
# ---------------------------------------------
#
# Healthcare reform, immigration policy, economic policy, and environmental policy are just a few of the key political issues that dominate the headlines. The Affordable Care Act, proposed changes to healthcare, and border control are all topics of debate in the healthcare and immigration spheres. Economic policy, including tax reform, government spending, and trade agreements, has a significant impact on Americans' daily lives. Finally, environmental policy, including climate change, energy production, and conservation, is a pressing concern for many.
#
# **The Impact of Political Polarization and Biased Media**
# -------------------------------------------------------
#
# Social media has dramatically changed the way we consume political news. With algorithms designed to keep us engaged, it's easy to fall prey to confirmation bias, where we only consume news that aligns with our existing beliefs. This can lead to a deepening of political polarization, making it difficult to engage in respectful conversations with those who hold differing opinions.
#
# So, how can you avoid bias in your news consumption? Evaluate sources carefully, considering factors like credibility and objectivity. Seek out diverse perspectives, and be open to changing your mind. In the era of fake news, it's essential to fact-check information before sharing.
#
# **Call to Action: Get Involved and Stay Informed**
# ---------------------------------------------------
#
# Now that you've gained a deeper understanding of US politics, it's time to get involved! Engage in respectful political conversations with friends, family, and colleagues. Stay informed about current events by following reputable news sources, listening to podcasts, and using social media responsibly. Consider volunteering for a political campaign, attending town hall meetings, or contacting your elected officials to make your voice heard.
#
# Resources:
# -----------
#
# * Pew Research Center: "Political Typology"
# * Brookings Institution: "A brief history of US immigration policy"
# * Congressional Budget Office: "The Budget and Economic Outlook"
# * National Institute of Environmental Health Sciences: "Climate Change"
# * FactCheck.org: "How to Spot Fake News"
# * USA.gov: "Contact Elected Officials"
#
# By following this comprehensive guide, you'll be well on your way to understanding US politics, staying up-to-date on current events, and developing confident opinions on political issues. Remember, respectful political conversations are key to moving forward in a positive direction.
#
#
# # Agent: Editor
# ## Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.
#
#
# # Agent: Editor
# ## Final Answer:
# **Understanding US Politics: A Comprehensive Guide**
# =====================================================
#
# **The Importance of Staying Informed**
# -------------------------------------
#
# In today's politically charged climate, staying informed is crucial. With the constant influx of news and opinions, it can be overwhelming to make sense of it all. However, by gaining a deeper understanding of the US political system, individuals can make informed decisions and engage in respectful conversations about current events. This article aims to provide a comprehensive overview of the US political system, key political issues, and the impact of political polarization and biased media.
#
# The importance of staying informed cannot be overstated. It allows individuals to make informed decisions, engage in respectful conversations, and hold elected officials accountable. In this article, we will delve into the basics of US politics, exploring the political system, key issues, and the impact of polarization and biased media.
#
# **The US Political System: A Breakdown**
# ----------------------------------------
#
# The US political system is composed of three branches of government: the Legislative, Executive, and Judicial branches. The Legislative branch, comprised of Congress, is responsible for making laws. The Executive branch, led by the President, carries out these laws. The Judicial branch, consisting of the Supreme Court, interprets these laws. In addition to these branches, political parties, such as the Democrats, Republicans, and Third Parties, play a significant role in shaping political discourse.
#
# The electoral process is another crucial aspect of US politics. Primary elections are held to select party nominees, followed by general elections, where voters choose between these nominees. The Electoral College, a system of electors who cast votes for president, is often a topic of discussion during election season. Understanding the electoral process is essential for making informed decisions at the polls.
#
# **Key Political Issues: Where Do You Stand?**
# ---------------------------------------------
#
# Several key political issues dominate the headlines, including healthcare reform, immigration policy, economic policy, and environmental policy. The Affordable Care Act, proposed changes to healthcare, and border control are all topics of debate in the healthcare and immigration spheres. Economic policy, including tax reform, government spending, and trade agreements, has a significant impact on Americans' daily lives. Finally, environmental policy, including climate change, energy production, and conservation, is a pressing concern for many.
#
# It is essential to stay informed about these key issues to develop confident opinions and engage in respectful conversations. By understanding the complexities of each issue, individuals can make informed decisions and contribute to meaningful discussions.
#
# **The Impact of Political Polarization and Biased Media**
# -------------------------------------------------------
#
# Social media has dramatically changed the way we consume political news. With algorithms designed to keep us engaged, it's easy to fall prey to confirmation bias, where we only consume news that aligns with our existing beliefs. This can lead to a deepening of political polarization, making it difficult to engage in respectful conversations with those who hold differing opinions.
#
# To avoid bias in your news consumption, evaluate sources carefully, considering factors like credibility and objectivity. Seek out diverse perspectives, and be open to changing your mind. In the era of fake news, it's essential to fact-check information before sharing. By being aware of these pitfalls, individuals can make informed decisions and engage in respectful conversations.
#
# **Call to Action: Get Involved and Stay Informed**
# ---------------------------------------------------
#
# Now that you've gained a deeper understanding of US politics, it's time to get involved! Engage in respectful political conversations with friends, family, and colleagues. Stay informed about current events by following reputable news sources, listening to podcasts, and using social media responsibly. Consider volunteering for a political campaign, attending town hall meetings, or contacting your elected officials to make your voice heard.
#
# Resources:
# -----------
#
# * Pew Research Center: "Political Typology"
# * Brookings Institution: "A brief history of US immigration policy"
# * Congressional Budget Office: "The Budget and Economic Outlook"
# * National Institute of Environmental Health Sciences: "Climate Change"
# * FactCheck.org: "How to Spot Fake News"
# * USA.gov: "Contact Elected Officials"
#
# By following this comprehensive guide, you'll be well on your way to understanding US politics, staying up-to-date on current events, and developing confident opinions on political issues. Remember, respectful political conversations are key to moving forward in a positive direction.

# %% [markdown]
# Display

# %%
from IPython.display import Markdown
Markdown(result.raw)
# Out:
# **Understanding US Politics: A Comprehensive Guide**
# =====================================================
#
# **The Importance of Staying Informed**
# -------------------------------------
#
# In today's politically charged climate, staying informed is crucial. With the constant influx of news and opinions, it can be overwhelming to make sense of it all. However, by gaining a deeper understanding of the US political system, individuals can make informed decisions and engage in respectful conversations about current events. This article aims to provide a comprehensive overview of the US political system, key political issues, and the impact of political polarization and biased media.
#
# The importance of staying informed cannot be overstated. It allows individuals to make informed decisions, engage in respectful conversations, and hold elected officials accountable. In this article, we will delve into the basics of US politics, exploring the political system, key issues, and the impact of polarization and biased media.
#
# **The US Political System: A Breakdown**
# ----------------------------------------
#
# The US political system is composed of three branches of government: the Legislative, Executive, and Judicial branches. The Legislative branch, comprised of Congress, is responsible for making laws. The Executive branch, led by the President, carries out these laws. The Judicial branch, consisting of the Supreme Court, interprets these laws. In addition to these branches, political parties, such as the Democrats, Republicans, and Third Parties, play a significant role in shaping political discourse.
#
# The electoral process is another crucial aspect of US politics. Primary elections are held to select party nominees, followed by general elections, where voters choose between these nominees. The Electoral College, a system of electors who cast votes for president, is often a topic of discussion during election season. Understanding the electoral process is essential for making informed decisions at the polls.
#
# **Key Political Issues: Where Do You Stand?**
# ---------------------------------------------
#
# Several key political issues dominate the headlines, including healthcare reform, immigration policy, economic policy, and environmental policy. The Affordable Care Act, proposed changes to healthcare, and border control are all topics of debate in the healthcare and immigration spheres. Economic policy, including tax reform, government spending, and trade agreements, has a significant impact on Americans' daily lives. Finally, environmental policy, including climate change, energy production, and conservation, is a pressing concern for many.
#
# It is essential to stay informed about these key issues to develop confident opinions and engage in respectful conversations. By understanding the complexities of each issue, individuals can make informed decisions and contribute to meaningful discussions.
#
# **The Impact of Political Polarization and Biased Media**
# -------------------------------------------------------
#
# Social media has dramatically changed the way we consume political news. With algorithms designed to keep us engaged, it's easy to fall prey to confirmation bias, where we only consume news that aligns with our existing beliefs. This can lead to a deepening of political polarization, making it difficult to engage in respectful conversations with those who hold differing opinions.
#
# To avoid bias in your news consumption, evaluate sources carefully, considering factors like credibility and objectivity. Seek out diverse perspectives, and be open to changing your mind. In the era of fake news, it's essential to fact-check information before sharing. By being aware of these pitfalls, individuals can make informed decisions and engage in respectful conversations.
#
# **Call to Action: Get Involved and Stay Informed**
# ---------------------------------------------------
#
# Now that you've gained a deeper understanding of US politics, it's time to get involved! Engage in respectful political conversations with friends, family, and colleagues. Stay informed about current events by following reputable news sources, listening to podcasts, and using social media responsibly. Consider volunteering for a political campaign, attending town hall meetings, or contacting your elected officials to make your voice heard.
#
# Resources:
# -----------
#
# * Pew Research Center: "Political Typology"
# * Brookings Institution: "A brief history of US immigration policy"
# * Congressional Budget Office: "The Budget and Economic Outlook"
# * National Institute of Environmental Health Sciences: "Climate Change"
# * FactCheck.org: "How to Spot Fake News"
# * USA.gov: "Contact Elected Officials"
#
# By following this comprehensive guide, you'll be well on your way to understanding US politics, staying up-to-date on current events, and developing confident opinions on political issues. Remember, respectful political conversations are key to moving forward in a positive direction.

# %% [markdown]
# # **Simple HTML webpage**

# %% [markdown]
# Define Custom Tools

# %%
from crewai.tools import BaseTool
from typing import Type
from pydantic import BaseModel, Field

# %% [markdown]
# Browse Google Image URLs

# %%
# !pip install serpapi==0.1.5
# Out:
# Requirement already satisfied: serpapi==0.1.5 in /usr/local/lib/python3.11/dist-packages (0.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from serpapi==0.1.5) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi==0.1.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi==0.1.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi==0.1.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->serpapi==0.1.5) (2025.6.15)

# %% [markdown]
# TOOL 1: Browse Google Images

# %%
import serpapi
class GetImagesInput(BaseModel):
    """Image keyword to search for getting image urls from the web"""
    image_keyword: str = Field(..., description="Image keyword to search for getting image urls from the web")

class GetImagesFromWeb(BaseTool):
    name: str = "Get_relevant_image_urls"
    description: str = "Search for the relevant image urls on web based on the given keyword"
    args_schema: Type[BaseModel] = GetImagesInput

    def _run(self, image_keyword: str) -> list:
        print("GetImagesFromWeb tool called")
        urlList = []
        try:
          params = {
            "q": str(image_keyword),
            "engine": "google_images",
            "ijn": "0",
            "api_key": "Your api key"
          }
          search = serpapi.search(params)
          for eachObject in search['images_results'][:10]:
            urlList.append(eachObject['original'])
          print("urlList is")
          print(urlList)
          return urlList
        except Exception as e:
          return urlList
# Instantiate the tool
get_image_urls_tool = GetImagesFromWeb()

# %% [markdown]
# TOOL 2: Save HTML file tool

# %%
class SaveHtmlFileInput(BaseModel):
    """Input schema for saving an HTML file."""
    html_page_content: str = Field(..., description="HTML file contents to save.")

class SaveHtmlFileTool(BaseTool):
    name: str = "Save_html_file"
    description: str = "Saves the given HTML content to a file named 'mywebpage.html'."
    args_schema: Type[BaseModel] = SaveHtmlFileInput

    def _run(self, html_page_content: str) -> str:
        filename = "mywebpage.html"
        try:
          with open(filename, "w", encoding="utf-8") as file:
              file.write(html_page_content)
          return f"File saved successfully as {filename}"
        except Exception as e:
            return f"Error saving file: {str(e)}"

# Instantiate the tool
save_file_tool = SaveHtmlFileTool()

# %% [markdown]
# Web Developer Agent

# %%
web_developer = Agent(
    llm=llm,
    role = "Senior Web developer",
    goal = "Compile the results into a HTML file.",
    backstory = "You are a competent Web developer writing HTML and CSS with decades of experience. "
                "You receives a blog post from the editor "
                "Your Goal is the convert the edited final draft of the blog post in a well structured HTML file "
                "The web page should be desgined beutifully using js or css"
                "You must include images(use image urls from web) and background colores which are relevant to the topic and content mentioned in the input file."
                "Pass short relevant keywords like 'indian cricket','America','Machine learning'..etc to the given `Get_relevant_image_urls` tool fr getting relevant image urls from web."
                "Dont pass long keywords or sentences to the `Get_relevant_image_urls` tool"
                "The output will be a single HTML file all the images,fonts, css and js should be embedded inside that file"
                "The webpage must be colorfull and attractive. Add background color and font color based on the context of the blog. But dont keep it as default"
                "Save the HTML file in the folder with name current_webpage.html use given `Save_html_file` tool for saving.",
    tools = [save_file_tool,get_image_urls_tool],
    allow_delegation=False,
    verbose=True
)

# %% [markdown]
# Web Developer Task

# %%
webpage_creation = Task(
    description=("Convert the given edited final draft of the blog post into a html file"),
    expected_output="A well-desgined HTML page which contain both images and texts and looks very pretty"
                    "The output will be a single HTML file all the images,fonts, css and js should be embedded inside that file. Pass short relevant keywords to the given tool and use given tool for getting relevant image urls from web."
                    "The webpage must be colorfull and attractive. Add background color and font color based on the context of the blog. But dont keep it as default"
                    "Save the HTML file in the folder with name current_webpage.html use python tool for saving.",

    agent=web_developer
)

# %% [markdown]
# Redefine the Crew

# %%
crew = Crew(
    agents=[planner, writer, editor,web_developer],
    tasks=[plan, write, edit,webpage_creation],
    verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %% [markdown]
# Kick Off

# %%
result = crew.kickoff(inputs={"topic": "Malayam Cinema History"})

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==1.7.0
# aiofiles==24.1.0
# aiohappyeyeballs==2.6.1
# aiohttp==3.11.15
# aiosignal==1.3.2
# alabaster==1.0.0
# albucore==0.0.24
# albumentations==2.0.8
# ale-py==0.11.1
# alembic==1.16.1
# altair==5.5.0
# annotated-types==0.7.0
# antlr4-python3-runtime==4.9.3
# anyio==4.9.0
# appdirs==1.4.4
# argon2-cffi==25.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.7.2
# arviz==0.21.0
# asgiref==3.8.1
# astropy==7.1.0
# astropy-iers-data==0.2025.6.2.0.38.23
# astunparse==1.6.3
# atpublic==5.1
# attrs==25.3.0
# audioread==3.0.1
# auth0-python==4.9.0
# autograd==1.8.0
# babel==2.17.0
# backcall==0.2.0
# backoff==2.2.1
# backports.tarfile==1.2.0
# bcrypt==4.3.0
# beautifulsoup4==4.13.4
# betterproto==2.0.0b6
# bigframes==2.5.0
# bigquery-magics==0.9.0
# bleach==6.2.0
# blinker==1.9.0
# blis==1.3.0
# blobfile==3.0.0
# blosc2==3.3.4
# bokeh==3.7.3
# Bottleneck==1.4.2
# bqplot==0.12.45
# branca==0.8.1
# build==1.2.2.post1
# CacheControl==0.14.3
# cachetools==5.5.2
# catalogue==2.0.10
# certifi==2025.4.26
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.2
# chex==0.1.89
# chroma-hnswlib==0.7.6
# chromadb==0.5.23
# clarabel==0.11.0
# click==8.2.1
# cloudpathlib==0.21.1
# cloudpickle==3.1.1
# cmake==3.31.6
# cmdstanpy==1.2.5
# cohere==5.15.0
# colorcet==3.1.0
# coloredlogs==15.0.1
# colorlover==0.3.0
# colour==0.1.5
# community==1.0.0b1
# confection==0.1.5
# cons==0.4.6
# contourpy==1.3.2
# cramjam==2.10.0
# crewai==0.86.0
# crewai-tools==0.25.0
# cryptography==43.0.3
# cuda-python==12.6.2.post1
# cudf-cu12 @ https://pypi.nvidia.com/cudf-cu12/cudf_cu12-25.2.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# cudf-polars-cu12==25.2.2
# cufflinks==0.17.3
# cuml-cu12==25.2.1
# cupy-cuda12x==13.3.0
# curl_cffi==0.11.1
# cuvs-cu12==25.2.1
# cvxopt==1.3.2
# cvxpy==1.6.5
# cycler==0.12.1
# cyipopt==1.5.0
# cymem==2.0.11
# Cython==3.0.12
# dask==2024.12.1
# dask-cuda==25.2.0
# dask-cudf-cu12==25.2.2
# dask-expr==1.1.21
# dataclasses-json==0.6.7
# dataproc-spark-connect==0.7.5
# datascience==0.17.6
# datasets==2.14.4
# db-dtypes==1.4.3
# dbus-python==1.2.18
# debugpy==1.8.0
# decorator==4.4.2
# defusedxml==0.7.1
# deprecation==2.1.0
# diffusers==0.33.1
# dill==0.3.7
# distributed==2024.12.1
# distributed-ucxx-cu12==0.42.0
# distro==1.9.0
# dlib==19.24.6
# dm-tree==0.1.9
# docker==7.1.0
# docker-pycreds==0.4.0
# docstring_parser==0.16
# docutils==0.21.2
# docx2txt==0.9
# dopamine_rl==4.1.2
# duckdb==1.2.2
# durationpy==0.10
# earthengine-api==1.5.18
# easydict==1.13
# editdistance==0.8.1
# eerepr==0.1.2
# einops==0.8.1
# embedchain==0.1.128
# en_core_web_sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl#sha256=1932429db727d4bff3deed6b34cfc05df17794f4a52eeb26cf8928f7c1a0fb85
# entrypoints==0.4
# et_xmlfile==2.0.0
# etils==1.12.2
# etuples==0.3.9
# Farama-Notifications==0.0.4
# fastai==2.7.19
# fastapi==0.115.9
# fastavro==1.11.1
# fastcore==1.7.29
# fastdownload==0.0.7
# fastjsonschema==2.21.1
# fastprogress==1.0.3
# fastrlock==0.8.3
# ffmpy==0.6.0
# filelock==3.18.0
# firebase-admin==6.8.0
# Flask==3.1.1
# flatbuffers==25.2.10
# flax==0.10.6
# folium==0.19.7
# fonttools==4.58.1
# frozendict==2.4.6
# frozenlist==1.6.0
# fsspec==2025.3.2
# future==1.0.0
# gast==0.6.0
# gcsfs==2025.3.2
# GDAL==3.8.4
# gdown==5.2.0
# geemap==0.35.3
# geocoder==1.38.1
# geographiclib==2.0
# geopandas==1.0.1
# geopy==2.4.1
# gin-config==0.5.0
# gitdb==4.0.12
# GitPython==3.1.44
# glob2==0.7
# google==2.0.3
# google-ai-generativelanguage==0.6.15
# google-api-core==2.25.0
# google-api-python-client==2.171.0
# google-auth==2.38.0
# google-auth-httplib2==0.2.0
# google-auth-oauthlib==1.2.2
# google-cloud-aiplatform==1.95.1
# google-cloud-bigquery==3.34.0
# google-cloud-bigquery-connection==1.18.2
# google-cloud-bigquery-storage==2.32.0
# google-cloud-core==2.4.3
# google-cloud-dataproc==5.18.1
# google-cloud-datastore==2.21.0
# google-cloud-firestore==2.21.0
# google-cloud-functions==1.20.3
# google-cloud-iam==2.19.0
# google-cloud-language==2.17.1
# google-cloud-resource-manager==1.14.2
# google-cloud-spanner==3.55.0
# google-cloud-storage==2.19.0
# google-cloud-translate==3.20.2
# google-colab @ file:///colabtools/dist/google_colab-1.0.0.tar.gz
# google-crc32c==1.7.1
# google-genai==1.18.0
# google-generativeai==0.8.5
# google-pasta==0.2.0
# google-resumable-media==2.7.2
# googleapis-common-protos==1.70.0
# googledrivedownloader==1.1.0
# gptcache==0.1.44
# gradio==5.31.0
# gradio_client==1.10.1
# graphviz==0.20.3
# greenlet==3.2.2
# groovy==0.1.2
# grpc-google-iam-v1==0.14.2
# grpc-interceptor==0.15.4
# grpcio==1.72.1
# grpcio-status==1.71.0
# grpclib==0.4.8
# gspread==6.2.1
# gspread-dataframe==4.0.0
# gym==0.25.2
# gym-notices==0.0.8
# gymnasium==1.1.1
# h11==0.16.0
# h2==4.2.0
# h5netcdf==1.6.1
# h5py==3.13.0
# hdbscan==0.8.40
# hf-xet==1.1.2
# hf_transfer==0.1.9
# highspy==1.10.0
# holidays==0.74
# holoviews==1.20.2
# hpack==4.1.0
# html5lib==1.1
# httpcore==1.0.9
# httpimport==1.4.1
# httplib2==0.22.0
# httptools==0.6.4
# httpx==0.28.1
# httpx-sse==0.4.0
# huggingface-hub==0.32.4
# humanfriendly==10.0
# humanize==4.12.3
# hyperframe==6.1.0
# hyperopt==0.2.7
# ibis-framework==9.5.0
# idna==3.10
# imageio==2.37.0
# imageio-ffmpeg==0.6.0
# imagesize==1.4.1
# imbalanced-learn==0.13.0
# immutabledict==4.2.1
# importlib_metadata==8.7.0
# importlib_resources==6.5.2
# imutils==0.5.4
# inflect==7.5.0
# iniconfig==2.1.0
# instructor==1.8.3
# intel-cmplr-lib-ur==2025.1.1
# intel-openmp==2025.1.1
# ipyevents==2.0.2
# ipyfilechooser==0.6.0
# ipykernel==6.17.1
# ipyleaflet==0.19.2
# ipyparallel==8.8.0
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipytree==0.2.2
# ipywidgets==7.7.1
# itsdangerous==2.2.0
# jaraco.classes==3.4.0
# jaraco.context==6.0.1
# jaraco.functools==4.1.0
# jax==0.5.2
# jax-cuda12-pjrt==0.5.1
# jax-cuda12-plugin==0.5.1
# jaxlib==0.5.1
# jedi==0.19.2
# jeepney==0.9.0
# jieba==0.42.1
# Jinja2==3.1.6
# jiter==0.8.2
# joblib==1.5.1
# json5==0.12.0
# json_repair==0.46.2
# jsonpatch==1.33
# jsonpickle==4.1.1
# jsonpointer==3.0.0
# jsonref==1.1.0
# jsonschema==4.24.0
# jsonschema-specifications==2025.4.1
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-leaflet==0.19.2
# jupyter-server==1.16.0
# jupyter_core==5.8.1
# jupyter_kernel_gateway @ git+https://github.com/googlecolab/kernel_gateway@b134e9945df25c2dcb98ade9129399be10788671
# jupyterlab_pygments==0.3.0
# jupyterlab_widgets==3.0.15
# jupytext==1.17.2
# kaggle==1.7.4.5
# kagglehub==0.3.12
# keras==3.8.0
# keras-hub==0.18.1
# keras-nlp==0.18.1
# keyring==25.6.0
# keyrings.google-artifactregistry-auth==1.1.2
# kiwisolver==1.4.8
# kubernetes==32.0.1
# lancedb==0.23.0
# langchain==0.3.25
# langchain-cohere==0.3.5
# langchain-community==0.0.29
# langchain-core==0.1.53
# langchain-experimental==0.3.4
# langchain-openai==0.2.14
# langchain-text-splitters==0.3.8
# langcodes==3.5.0
# langsmith==0.1.147
# language_data==1.3.0
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lazy_loader==0.4
# libclang==18.1.1
# libcudf-cu12 @ https://pypi.nvidia.com/libcudf-cu12/libcudf_cu12-25.2.1-py3-none-manylinux_2_28_x86_64.whl
# libcugraph-cu12==25.2.0
# libcuml-cu12==25.2.1
# libcuvs-cu12==25.2.1
# libkvikio-cu12==25.2.1
# libpysal==4.13.0
# libraft-cu12==25.2.0
# librosa==0.11.0
# libucx-cu12==1.18.1
# libucxx-cu12==0.42.0
# lightgbm @ file:///tmp/lightgbm/LightGBM/dist/lightgbm-4.5.0-py3-none-linux_x86_64.whl
# linkify-it-py==2.0.3
# litellm==1.68.0
# llvmlite==0.43.0
# locket==1.0.0
# logical-unification==0.4.6
# lxml==5.4.0
# Mako==1.1.3
# marisa-trie==1.2.1
# Markdown==3.8
# markdown-it-py==3.0.0
# MarkupSafe==3.0.2
# marshmallow==3.26.1
# matplotlib==3.10.0
# matplotlib-inline==0.1.7
# matplotlib-venn==1.1.2
# mdit-py-plugins==0.4.2
# mdurl==0.1.2
# mem0ai==0.1.104
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==3.1.3
# mizani==0.13.5
# mkl==2025.0.1
# ml-dtypes==0.4.1
# mlxtend==0.23.4
# mmh3==5.1.0
# monotonic==1.6
# more-itertools==10.7.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.1.0
# multidict==6.4.4
# multipledispatch==1.0.0
# multiprocess==0.70.15
# multitasking==0.0.11
# murmurhash==1.0.13
# music21==9.3.0
# mypy_extensions==1.1.0
# namex==0.1.0
# narwhals==1.41.0
# natsort==8.4.0
# nbclassic==1.3.1
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# ndindex==1.10.0
# nest-asyncio==1.6.0
# networkx==3.5
# nibabel==5.3.2
# nltk==3.9.1
# nodeenv==1.9.1
# notebook==6.5.7
# notebook_shim==0.2.4
# numba==0.60.0
# numba-cuda==0.2.0
# numexpr==2.10.2
# numpy==1.26.4
# nvidia-cublas-cu12==12.5.3.2
# nvidia-cuda-cupti-cu12==12.5.82
# nvidia-cuda-nvcc-cu12==12.5.82
# nvidia-cuda-nvrtc-cu12==12.5.82
# nvidia-cuda-runtime-cu12==12.5.82
# nvidia-cudnn-cu12==9.3.0.75
# nvidia-cufft-cu12==11.2.3.61
# nvidia-curand-cu12==10.3.6.82
# nvidia-cusolver-cu12==11.6.3.83
# nvidia-cusparse-cu12==12.5.1.3
# nvidia-cusparselt-cu12==0.6.2
# nvidia-ml-py==12.575.51
# nvidia-nccl-cu12==2.21.5
# nvidia-nvcomp-cu12==4.2.0.11
# nvidia-nvjitlink-cu12==12.5.82
# nvidia-nvtx-cu12==12.4.127
# nvtx==0.2.12
# nx-cugraph-cu12 @ https://pypi.nvidia.com/nx-cugraph-cu12/nx_cugraph_cu12-25.2.0-py3-none-any.whl
# oauth2client==4.1.3
# oauthlib==3.2.2
# omegaconf==2.3.0
# onnxruntime==1.22.0
# openai==1.75.0
# opencv-contrib-python==4.11.0.86
# opencv-python==4.11.0.86
# opencv-python-headless==4.11.0.86
# openpyxl==3.1.5
# opentelemetry-api==1.34.0
# opentelemetry-exporter-otlp-proto-common==1.34.0
# opentelemetry-exporter-otlp-proto-grpc==1.34.0
# opentelemetry-exporter-otlp-proto-http==1.34.0
# opentelemetry-instrumentation==0.55b0
# opentelemetry-instrumentation-asgi==0.55b0
# opentelemetry-instrumentation-fastapi==0.55b0
# opentelemetry-proto==1.34.0
# opentelemetry-sdk==1.34.0
# opentelemetry-semantic-conventions==0.55b0
# opentelemetry-util-http==0.55b0
# opt_einsum==3.4.0
# optax==0.2.4
# optree==0.16.0
# orbax-checkpoint==0.11.13
# orjson==3.10.18
# osqp==1.0.4
# outcome==1.3.0.post0
# overrides==7.7.0
# packaging==23.2
# pandas==2.2.2
# pandas-datareader==0.10.0
# pandas-gbq==0.29.0
# pandas-stubs==2.2.2.240909
# pandocfilters==1.5.1
# panel==1.7.1
# param==2.2.0
# parso==0.8.4
# parsy==2.1
# partd==1.4.2
# pathlib==1.0.1
# patsy==1.0.1
# pdfminer.six==20250327
# pdfplumber==0.11.6
# peewee==3.18.1
# peft==0.15.2
# pexpect==4.9.0
# pickleshare==0.7.5
# pillow==11.2.1
# platformdirs==4.3.8
# plotly==5.24.1
# plotnine==0.14.5
# pluggy==1.6.0
# ply==3.11
# polars==1.21.0
# pooch==1.8.2
# portalocker==2.10.1
# portpicker==1.5.2
# posthog==3.25.0
# preshed==3.0.10
# prettytable==3.16.0
# proglog==0.1.12
# progressbar2==4.5.0
# prometheus_client==0.22.1
# promise==2.3
# prompt_toolkit==3.0.51
# propcache==0.3.1
# prophet==1.1.7
# proto-plus==1.26.1
# protobuf==5.29.5
# psutil==5.9.5
# psycopg2==2.9.10
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==18.1.0
# pyasn1==0.6.1
# pyasn1_modules==0.4.2
# pycairo==1.28.0
# pycocotools==2.0.9
# pycparser==2.22
# pycryptodomex==3.23.0
# pydantic==2.11.5
# pydantic-settings==2.9.1
# pydantic_core==2.33.2
# pydata-google-auth==1.9.1
# pydot==3.0.4
# pydotplus==2.0.2
# PyDrive==1.3.1
# PyDrive2==1.21.3
# pydub==0.25.1
# pyerfa==2.0.1.5
# pygame==2.6.1
# pygit2==1.18.0
# Pygments==2.19.1
# PyGObject==3.42.0
# PyJWT==2.10.1
# pylibcudf-cu12 @ https://pypi.nvidia.com/pylibcudf-cu12/pylibcudf_cu12-25.2.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# pylibcugraph-cu12==25.2.0
# pylibraft-cu12==25.2.0
# pymc==5.23.0
# pymystem3==0.2.0
# pynndescent==0.5.13
# pynvjitlink-cu12==0.6.0
# pynvml==12.0.0
# pyogrio==0.11.0
# pyomo==6.9.2
# PyOpenGL==3.1.9
# pyOpenSSL==24.2.1
# pyparsing==3.2.3
# pypdf==5.6.0
# pypdfium2==4.30.1
# pyperclip==1.9.0
# PyPika==0.48.9
# pyproj==3.7.1
# pyproject_hooks==1.2.0
# pyright==1.1.401
# pysbd==0.3.4
# pyshp==2.3.1
# PySocks==1.7.1
# pyspark==3.5.1
# pytensor==2.31.3
# pytest==8.3.5
# python-apt==0.0.0
# python-box==7.3.2
# python-dateutil==2.9.0.post0
# python-dotenv==1.1.0
# python-louvain==0.16
# python-multipart==0.0.20
# python-slugify==8.0.4
# python-snappy==0.7.3
# python-utils==3.9.1
# pytube==15.0.0
# pytz==2025.2
# pyvis==0.3.2
# pyviz_comms==3.0.4
# PyWavelets==1.8.0
# PyYAML==6.0.2
# pyzmq==24.0.1
# qdrant-client==1.14.2
# raft-dask-cu12==25.2.0
# rapids-dask-dependency==25.2.0
# ratelim==0.1.6
# referencing==0.36.2
# regex==2024.11.6
# requests==2.32.3
# requests-oauthlib==2.0.0
# requests-toolbelt==1.0.0
# requirements-parser==0.9.0
# rich==13.9.4
# rmm-cu12==25.2.0
# roman-numerals-py==3.1.0
# rpds-py==0.25.1
# rpy2==3.5.17
# rsa==4.9.1
# ruff==0.11.12
# safehttpx==0.1.6
# safetensors==0.5.3
# schema==0.7.7
# scikit-image==0.25.2
# scikit-learn==1.6.1
# scipy==1.15.3
# scooby==0.10.1
# scrapegraph_py==1.12.0
# scs==3.2.7.post2
# seaborn==0.13.2
# SecretStorage==3.3.3
# selenium==4.33.0
# semantic-version==2.10.0
# Send2Trash==1.8.3
# sentence-transformers==4.1.0
# sentencepiece==0.2.0
# sentry-sdk==2.29.1
# serpapi==0.1.5
# setproctitle==1.3.6
# shap==0.47.2
# shapely==2.1.1
# shellingham==1.5.4
# simple-parsing==0.1.7
# simplejson==3.20.1
# simsimd==6.4.7
# six==1.17.0
# sklearn-compat==0.1.3
# sklearn-pandas==2.2.0
# slicer==0.0.8
# smart-open==7.1.0
# smmap==5.0.2
# sniffio==1.3.1
# snowballstemmer==3.0.1
# sortedcontainers==2.4.0
# soundfile==0.13.1
# soupsieve==2.7
# soxr==0.5.0.post1
# spacy==3.8.7
# spacy-legacy==3.0.12
# spacy-loggers==1.0.5
# spanner-graph-notebook==1.1.6
# Sphinx==8.2.3
# sphinxcontrib-applehelp==2.0.0
# sphinxcontrib-devhelp==2.0.0
# sphinxcontrib-htmlhelp==2.1.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==2.0.0
# sphinxcontrib-serializinghtml==2.0.0
# SQLAlchemy==2.0.41
# sqlglot==25.20.2
# sqlparse==0.5.3
# srsly==2.5.1
# stanio==0.5.1
# starlette==0.45.3
# statsmodels==0.14.4
# stringzilla==3.12.5
# stumpy==1.13.0
# sympy==1.13.1
# tables==3.10.2
# tabulate==0.9.0
# tbb==2022.1.0
# tblib==3.1.0
# tcmlib==1.3.0
# tenacity==8.5.0
# tensorboard==2.18.0
# tensorboard-data-server==0.7.2
# tensorflow==2.18.0
# tensorflow-datasets==4.9.9
# tensorflow-hub==0.16.1
# tensorflow-io-gcs-filesystem==0.37.1
# tensorflow-metadata==1.17.1
# tensorflow-probability==0.25.0
# tensorflow-text==2.18.1
# tensorflow_decision_forests==1.11.0
# tensorstore==0.1.74
# termcolor==3.1.0
# terminado==0.18.1
# text-unidecode==1.3
# textblob==0.19.0
# tf-slim==1.1.0
# tf_keras==2.18.0
# thinc==8.3.6
# threadpoolctl==3.6.0
# tifffile==2025.6.1
# tiktoken==0.9.0
# timm==1.0.15
# tinycss2==1.4.0
# tokenizers==0.20.3
# toml==0.10.2
# tomli==2.2.1
# tomli_w==1.2.0
# tomlkit==0.13.2
# toolz==0.12.1
# torch @ https://download.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl
# torchao==0.10.0
# torchaudio @ https://download.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp311-cp311-linux_x86_64.whl
# torchdata==0.11.0
# torchsummary==1.5.1
# torchtune==0.6.1
# torchvision @ https://download.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp311-cp311-linux_x86_64.whl
# tornado==6.4.2
# tqdm==4.67.1
# traitlets==5.7.1
# traittypes==0.2.1
# transformers==4.52.4
# treelite==4.4.1
# treescope==0.1.9
# trio==0.30.0
# trio-websocket==0.12.2
# triton==3.2.0
# tsfresh==0.21.0
# tweepy==4.15.0
# typeguard==4.4.2
# typer==0.16.0
# types-pytz==2025.2.0.20250516
# types-requests==2.32.0.20250602
# types-setuptools==80.9.0.20250529
# typing-inspect==0.9.0
# typing-inspection==0.4.1
# typing_extensions==4.13.2
# tzdata==2025.2
# tzlocal==5.3.1
# uc-micro-py==1.0.3
# ucx-py-cu12==0.42.0
# ucxx-cu12==0.42.0
# umap-learn==0.5.7
# umf==0.10.0
# uritemplate==4.2.0
# urllib3==2.4.0
# uv==0.7.12
# uvicorn==0.34.3
# uvloop==0.21.0
# vega-datasets==0.9.0
# wadllib==1.3.6
# wandb==0.19.11
# wasabi==1.1.3
# watchfiles==1.0.5
# wcwidth==0.2.13
# weasel==0.4.1
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# websockets==15.0.1
# Werkzeug==3.1.3
# widgetsnbextension==3.6.10
# wordcloud==1.9.4
# wrapt==1.17.2
# wsproto==1.2.0
# wurlitzer==3.1.1
# xarray==2025.3.1
# xarray-einstats==0.9.0
# xgboost==2.1.4
# xlrd==2.0.1
# xxhash==3.5.0
# xyzservices==2025.4.0
# yarl==1.20.0
# ydf==0.12.0
# yellowbrick==1.5
# yfinance==0.2.61
# zict==3.0.0
# zipp==3.22.0
# zstandard==0.23.0
